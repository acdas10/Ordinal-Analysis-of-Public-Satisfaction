# %%
import pandas as pd
import re

# %%
data_main = pd.read_csv('data_main.csv')

# %%
data_main.head()
# Out:
#                        Timestamp  What is your birth year? (e.g. 1998)  \
# 215  2025/05/25 12:20:50 pm EEST                                  2006
# 216  2025/05/25 12:20:52 pm EEST                                  2005
# 217  2025/05/25 12:21:05 pm EEST                                  2003
# 218   2025/05/25 4:29:16 pm EEST                                  2005
# 219   2025/08/03 2:04:08 am EEST                                  1999
#
#     Gender?   What is your highest level of education?    \
# 215    Male                                          HSC
# 216    Male                                     Bachelor
# 217    Male                                          HSC
# 218    Male                                     Bachelor
# 219    Male                                          HSC
#
#       What industry do you work in?    \
# 215                           Student
# 216                           Student
# 217                           Student
# 218                           Student
# 219                           Student
#
#       How would you rate your technical knowledge of AI?    \
# 215                                       Intermediate
# 216                                             Expert
# 217                                       Intermediate
# 218                                           Beginner
# 219                                             Expert
#
#       How often do you use AI-powered tools?    \
# 215                        Weekly- A few times
# 216                        Weekly- A few times
# 217                                      Daily
# 218                        Weekly- A few times
# 219                                      Daily
#
#     What AI-powered services do you use most frequently? \n(You can choose multiple)   \
# 215                           ChatGPT;Google Assistant
# 216                                            ChatGPT
# 217                                  ChatGPT;Deep Seek
# 218                           ChatGPT;Google Assistant
# 219          ChatGPT;Gemini;Deep Seek;Google Assistant
#
#                Why do you typically use AI?    \
# 215             Coding;Personal-Use;Education
# 216                             Data-Analysis
# 217      Data-Analysis;Personal-Use;Education
# 218         Personal-Use;Assignment;Education
# 219  Coding;Personal-Use;Assignment;Education
#
#     Have you noticed AI-generated content (e.g., news, ads, recommendations) influencing your choices in any of the following?     \
# 215  Social media content consumption;Education/lea...
# 216                   Social media content consumption
# 217         Career decisions;Education/learning habits
# 218  Online shopping;Social media content consumpti...
# 219   Online shopping;Social media content consumption
#
#      ...  \
# 215  ...
# 216  ...
# 217  ...
# 218  ...
# 219  ...
#
#     Do you think we should trust AI to make critical decisions in  Customer Service (e.g., AI chatbots solving queries)?  \
# 215                                                Yes
# 216                                                 No
# 217                                              Maybe
# 218                                              Maybe
# 219                                                Yes
#
#     How much do you trust AI to make critical decisions in Customer Service?  \
# 215                                                  4
# 216                                                  4
# 217                                                  3
# 218                                                  3
# 219                                                  5
#
#     Have you ever experienced an AI-driven decision that felt unfair or biased?  \
# 215                                                 No
# 216                                                Yes
# 217                                              Maybe
# 218                                              Maybe
# 219                                                Yes
#
#      Do you believe AI will replace jobs in your industry within the next 10 years?    \
# 215                                                 No
# 216                             Yes-but-not-completely
# 217                                             Unsure
# 218                                                Yes
# 219                                                 No
#
#     Do you believe AI will create more jobs than it eliminates?    \
# 215                                                 No
# 216                                              Maybe
# 217                                              Maybe
# 218                                              Maybe
# 219                                                Yes
#
#      Are you actively learning new skills to adapt to AI-driven changes in the job market?    \
# 215                                                Yes
# 216                                                Yes
# 217                                                Yes
# 218                             No-Effect-in-my-career
# 219                                                Yes
#
#               What is your biggest concern about AI?    \
# 215  Privacy and data security risks;AI replacing h...
# 216                    Privacy and data security risks
# 217                    Privacy and data security risks
# 218  AI being used for misinformation and deepfakes...
# 219  Job loss and automation replacing workers;Priv...
#
#      Do you think AI should be more strictly regulated by governments?    \
# 215                 Sometimes, but not too restrictive
# 216                 Sometimes, but not too restrictive
# 217      Yes, AI should have strong legal restrictions
# 218                 Sometimes, but not too restrictive
# 219      Yes, AI should have strong legal restrictions
#
#     Do you believe AI should be required to disclose when its content is AI-generated?    \
# 215  Only in certain cases (e.g., news, official do...
# 216  Only in certain cases (e.g., news, official do...
# 217  Only in certain cases (e.g., news, official do...
# 218  Yes, AI-generated content should always be lab...
# 219  Yes, AI-generated content should always be lab...
#
#      How do you feel about AI making creative works (e.g., writing books, making music, generating art)?
# 215    AI-generated content is exciting and beneficial
# 216                       It depends on how AI is used
# 217  AI-generated content is concerning and threate...
# 218    AI-generated content is exciting and beneficial
# 219                       It depends on how AI is used
#
# [5 rows x 30 columns]

# %%
data_main.columns
# Out:
# Index(['Timestamp', 'What is your birth year? (e.g. 1998)', 'Gender?',
#        '  What is your highest level of education?  ',
#        '  What industry do you work in?  ',
#        '  How would you rate your technical knowledge of AI?  ',
#        '  How often do you use AI-powered tools?  ',
#        'What AI-powered services do you use most frequently? \n(You can choose multiple) ',
#        '  Why do you typically use AI?  ',
#        'Have you noticed AI-generated content (e.g., news, ads, recommendations) influencing your choices in any of the following?   ',
#        'Do you think that AI recommendation based on your own choice is helping you?',
#        'Do you think that we should be more concern about using AI system?',
#        'Do you think we should trust AI to make critical decisions in  Healthcare (e.g., AI diagnosing diseases)?',
#        'How much do you trust AI to make critical decisions in Healthcare?',
#        'Do you think we should trust AI to make critical decisions in  Finance (e.g., AI approving loans or detecting fraud)?',
#        'How much do you trust AI to make critical decisions in Finance?',
#        'Do you think we should trust AI to make critical decisions in  Hiring & Recruitment (e.g., AI screening job applications)?',
#        'How much do you trust AI to make critical decisions in Hiring and Recruitment?',
#        'Do you think we should trust AI to make critical decisions in  Education (e.g., AI-assisted learning, grading systems)?',
#        'How much do you trust AI to make critical decisions in Education?',
#        'Do you think we should trust AI to make critical decisions in  Customer Service (e.g., AI chatbots solving queries)?',
#        'How much do you trust AI to make critical decisions in Customer Service?',
#        'Have you ever experienced an AI-driven decision that felt unfair or biased?',
#        'Do you believe AI will replace jobs in your industry within the next 10 years?  ',
#        'Do you believe AI will create more jobs than it eliminates?  ',
#        'Are you actively learning new skills to adapt to AI-driven changes in the job market?  ',
#        'What is your biggest concern about AI?  ',
#        'Do you think AI should be more strictly regulated by governments?  ',
#        'Do you believe AI should be required to disclose when its content is AI-generated?  ',
#        'How do you feel about AI making creative works (e.g., writing books, making music, generating art)?  '],
#       dtype='object')

# %%
data_main.columns = data_main.columns.str.strip().str.replace("\n", " ", regex=True)

# %%
data = data_main.iloc[:, 1:12]

# %%
data.head()
# Out:
#    What is your birth year? (e.g. 1998) Gender?  \
# 0                                  1997    Male
# 1                                  1995    Male
# 2                                  2001  Female
# 3                                  1973  Female
# 4                                  1996  Female
#
#   What is your highest level of education? What industry do you work in?  \
# 0                                 Bachelor                     Education
# 1                                 Bachelor                       Student
# 2                                      HSC                       Student
# 3                                      HSC                        Others
# 4                                 Bachelor                 Technology-IT
#
#   How would you rate your technical knowledge of AI?  \
# 0                                             Expert
# 1                                             Expert
# 2                                       Intermediate
# 3                                                NaN
# 4                                       Intermediate
#
#   How often do you use AI-powered tools?  \
# 0                                  Daily
# 1                                  Daily
# 2                    Weekly- A few times
# 3                   Monthly- A few times
# 4                                  Daily
#
#   What AI-powered services do you use most frequently?  (You can choose multiple)  \
# 0                                     ChatGPT;Gemini
# 1          ChatGPT;Gemini;Google Assistant;Grammarly
# 2                            Gemini;Google Assistant
# 3                                   Google Assistant
# 4                      ChatGPT;Gemini;Siri;Grammarly
#
#                         Why do you typically use AI?  \
# 0  Data-Analysis;Coding;Personal-Use;Assignment;E...
# 1  Data-Analysis;Coding;Personal-Use;Assignment;E...
# 2                             Personal-Use;Education
# 3                                       Personal-Use
# 4  Data-Analysis;Coding;Personal-Use;Assignment;E...
#
#   Have you noticed AI-generated content (e.g., news, ads, recommendations) influencing your choices in any of the following?  \
# 0   Online shopping;Social media content consumption
# 1  Online shopping;Social media content consumpti...
# 2   Online shopping;Social media content consumption
# 3                                  None of the above
# 4          Online shopping;Education/learning habits
#
#   Do you think that AI recommendation based on your own choice is helping you?  \
# 0                                              Maybe
# 1                                                Yes
# 2                                                Yes
# 3                                                 No
# 4                                                Yes
#
#   Do you think that we should be more concern about using AI system?
# 0                                                Yes
# 1                                                Yes
# 2                                              Maybe
# 3                                                Yes
# 4                                                Yes

# %%
new_names = {
    "What is your birth year? (e.g. 1998)": "BirthYear",
    "Gender?": "Gender",
    "What is your highest level of education?": "Education",
    "What industry do you work in?": "Industry",
    "How would you rate your technical knowledge of AI?": "AI_Knowledge",
    "How often do you use AI-powered tools?": "AI_Usage",
    "What AI-powered services do you use most frequently?  (You can choose multiple)": "AI_Services",
    "Why do you typically use AI?": "AI_Purpose",
    "Have you noticed AI-generated content (e.g., news, ads, recommendations) influencing your choices in any of the following?": "AI_Influence",
    "Do you think that AI recommendation based on your own choice is helping you?": "AI_Helpfulness",
    "Do you think that we should be more concern about using AI system?": "AI_Concern"
}

data = data.rename(columns=new_names)

# %%
data.head()
# Out:
#    BirthYear  Gender Education       Industry  AI_Knowledge  \
# 0       1997    Male  Bachelor      Education        Expert
# 1       1995    Male  Bachelor        Student        Expert
# 2       2001  Female       HSC        Student  Intermediate
# 3       1973  Female       HSC         Others           NaN
# 4       1996  Female  Bachelor  Technology-IT  Intermediate
#
#                AI_Usage                                AI_Services  \
# 0                 Daily                             ChatGPT;Gemini
# 1                 Daily  ChatGPT;Gemini;Google Assistant;Grammarly
# 2   Weekly- A few times                    Gemini;Google Assistant
# 3  Monthly- A few times                           Google Assistant
# 4                 Daily              ChatGPT;Gemini;Siri;Grammarly
#
#                                           AI_Purpose  \
# 0  Data-Analysis;Coding;Personal-Use;Assignment;E...
# 1  Data-Analysis;Coding;Personal-Use;Assignment;E...
# 2                             Personal-Use;Education
# 3                                       Personal-Use
# 4  Data-Analysis;Coding;Personal-Use;Assignment;E...
#
#                                         AI_Influence AI_Helpfulness AI_Concern
# 0   Online shopping;Social media content consumption          Maybe        Yes
# 1  Online shopping;Social media content consumpti...            Yes        Yes
# 2   Online shopping;Social media content consumption            Yes      Maybe
# 3                                  None of the above             No        Yes
# 4          Online shopping;Education/learning habits            Yes        Yes

# %%
target_cols = ['Gender', 'Education', 'AI_Knowledge', 'AI_Usage', 'AI_Helpfulness', 'AI_Concern']

for col in target_cols:
    print(f"--- {col} Breakdown ---")
    # Combine counts and percentages into a mini table
    counts = data[col].value_counts()
    percent = data[col].value_counts(normalize=True) * 100
    
    # Create a temporary DataFrame to show them side-by-side
    summary = pd.DataFrame({'Count': counts, 'Percentage (%)': percent})
    print(summary)
    print("\n")
# Out:
# --- Gender Breakdown ---
#         Count  Percentage (%)
# Gender
# Male      158       71.818182
# Female     62       28.181818
#
#
# --- Education Breakdown ---
#            Count  Percentage (%)
# Education
# HSC          116       52.727273
# Bachelor      72       32.727273
# Master        28       12.727273
# PhD            3        1.363636
# SSC            1        0.454545
#
#
# --- AI_Knowledge Breakdown ---
#               Count  Percentage (%)
# AI_Knowledge
# Beginner        132       67.346939
# Intermediate     51       26.020408
# Expert           13        6.632653
#
#
# --- AI_Usage Breakdown ---
#                       Count  Percentage (%)
# AI_Usage
# Daily                   144       65.454545
# Weekly- A few times      52       23.636364
# Monthly- A few times     15        6.818182
# Never                     9        4.090909
#
#
# --- AI_Helpfulness Breakdown ---
#                 Count  Percentage (%)
# AI_Helpfulness
# Yes               124       56.363636
# Maybe              91       41.363636
# No                  5        2.272727
#
#
# --- AI_Concern Breakdown ---
#             Count  Percentage (%)
# AI_Concern
# Yes           176       80.000000
# Maybe          34       15.454545
# No             10        4.545455

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# List of target columns
target_cols = ['Gender', 'Education', 'AI_Knowledge', 'AI_Usage', 'AI_Helpfulness', 'AI_Concern']

# Set the visual style
sns.set_theme(style="whitegrid")

# Swapped to 2 rows and 3 columns. Figsize adjusted for a horizontal layout.
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(15, 8))
axes = axes.flatten()

for i, col in enumerate(target_cols):
    # Calculate raw counts and percentages
    counts = data[col].value_counts()
    percentages = data[col].value_counts(normalize=True) * 100
    
    # Create the bar plot
    sns.barplot(x=counts.index, y=counts.values, ax=axes[i], hue=counts.index, legend=False, palette="viridis")
    
    # Add percentage labels on top of each bar
    for p, percent in zip(axes[i].patches, percentages):
        axes[i].annotate(f'{percent:.1f}%', 
                         (p.get_x() + p.get_width() / 2., p.get_height()), 
                         ha='center', va='bottom', 
                         fontsize=9, fontweight='bold', xytext=(0, 3),
                         textcoords='offset points')
    
    # Formatting
    axes[i].set_title(f'Distribution of {col}', fontsize=12, fontweight='bold')
    axes[i].set_ylabel('Count', fontsize=10)
    axes[i].set_xlabel('')
    axes[i].tick_params(axis='x', rotation=30, labelsize=9)

# Adjust layout to prevent overlap
plt.tight_layout()
plt.show()

# %%
data["BirthYear"].value_counts()
# Out:
# BirthYear
# 2004    52
# 2005    43
# 2003    28
# 2006    13
# 2002    11
# 1997    11
# 2000    10
# 2001    10
# 1998     9
# 1996     7
# 1995     7
# 1999     6
# 1994     3
# 2007     3
# 1992     2
# 1993     2
# 1986     1
# 1973     1
# 1988     1
# Name: count, dtype: int64

# %%
data['Age'] = 2025 - data['BirthYear']  # or current year
data = data.drop(columns=['BirthYear'])

# %%
data_encoded = pd.get_dummies(data, columns=['Gender','Education','Industry','AI_Knowledge','AI_Usage','AI_Helpfulness', 'AI_Concern'])
data_encoded = data_encoded

# %%
# Find all columns that are currently of the boolean type (True/False)
boolean_cols = data_encoded.select_dtypes(include='bool').columns

# Convert *only* those selected boolean columns to integer (1/0)
data_encoded[boolean_cols] = data_encoded[boolean_cols].astype(int)

# %%
categorical_column = ["AI_Services", "AI_Purpose", "AI_Influence"]

# %%
for name in categorical_column:
    data_encoded[name] = data_encoded[name].str.split(";")
    data_encoded_exploded = data_encoded.explode(name)
    data_encoded_services = pd.get_dummies(data_encoded_exploded[name]).groupby(data_encoded_exploded.index).sum()
    data_encoded = data_encoded.drop(name, axis=1).join(data_encoded_services)

# %%
data = data_encoded

# %%
data.tail()
# Out:
#      Age  Gender_Female  Gender_Male  Education_Bachelor  Education_HSC  \
# 215   19              0            1                   0              1
# 216   20              0            1                   1              0
# 217   22              0            1                   0              1
# 218   20              0            1                   1              0
# 219   26              0            1                   0              1
#
#      Education_Master  Education_PhD  Education_SSC  Industry_Education  \
# 215                 0              0              0                   0
# 216                 0              0              0                   0
# 217                 0              0              0                   0
# 218                 0              0              0                   0
# 219                 0              0              0                   0
#
#      Industry_Finance  ...  Education  Medical  Personal-Use  Project works  \
# 215                 0  ...          1        0             1              0
# 216                 0  ...          0        0             0              0
# 217                 0  ...          1        0             1              0
# 218                 0  ...          1        0             1              0
# 219                 0  ...          1        0             1              0
#
#      Translation, Presentation, Severel Writings  Career decisions  \
# 215                                            0                 0
# 216                                            0                 0
# 217                                            0                 1
# 218                                            0                 1
# 219                                            0                 0
#
#      Education/learning habits  None of the above  Online shopping  \
# 215                          1                  0                0
# 216                          0                  0                0
# 217                          1                  0                0
# 218                          1                  0                1
# 219                          0                  0                1
#
#      Social media content consumption
# 215                                 1
# 216                                 1
# 217                                 0
# 218                                 1
# 219                                 1
#
# [5 rows x 52 columns]

# %%
data.isna().sum()
# Out:
# Age                                            0
# Gender_Female                                  0
# Gender_Male                                    0
# Education_Bachelor                             0
# Education_HSC                                  0
# Education_Master                               0
# Education_PhD                                  0
# Education_SSC                                  0
# Industry_Education                             0
# Industry_Finance                               0
# Industry_Healthcare                            0
# Industry_Marketing-Media                       0
# Industry_Others                                0
# Industry_Student                               0
# Industry_Technology-IT                         0
# AI_Knowledge_Beginner                          0
# AI_Knowledge_Expert                            0
# AI_Knowledge_Intermediate                      0
# AI_Usage_Daily                                 0
# AI_Usage_Monthly- A few times                  0
# AI_Usage_Never                                 0
# AI_Usage_Weekly- A few times                   0
# AI_Helpfulness_Maybe                           0
# AI_Helpfulness_No                              0
# AI_Helpfulness_Yes                             0
# AI_Concern_Maybe                               0
# AI_Concern_No                                  0
# AI_Concern_Yes                                 0
# Alexa                                          0
# ChatGPT                                        0
# Deep Seek                                      0
# Gemini                                         0
# Google Assistant                               0
# Grammarly                                      0
# None-above                                     0
# Notion-AI                                      0
# Siri                                           0
#                                                0
# Assignment                                     0
# Automation                                     0
# Coding                                         0
# Data-Analysis                                  0
# Education                                      0
# Medical                                        0
# Personal-Use                                   0
# Project works                                  0
# Translation, Presentation, Severel Writings    0
# Career decisions                               0
# Education/learning habits                      0
# None of the above                              0
# Online shopping                                0
# Social media content consumption               0
# dtype: int64

# %%
data.to_csv('prepared_data.csv')
